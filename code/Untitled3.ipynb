# %%
import pandas as pd

# %%
player_df = pd.read_csv('MAIN.csv')
player_df=player_df[['batter', 'player_name']]
player_df = player_df.drop_duplicates()
player_dict = {}

#player_dict =player_df.to_dict(player_df)
#for name in player_df:
 #   print(name)
    #player_dict[name['batter']] = name['player_name']
 

#for name in player_df:
   # print(name)
    
for name, row in player_df[:].iterrows():
    
    player_dict[row['batter']]=row['player_name']
    #print(row['batter'], row['player_name'])

#for batter,name in (zip (player_df['batter'],player_df['player_name'])):

 #   player_dict[batter] = player_dict[name]

#print(player_dict)
player_dict
# Out:
# batter
# player_name
# {457763: 'Posey, Buster',
#  673451: 'Akiyama, Shogo',
#  645277: 'Albies, Ozzie',
#  641684: 'Hermosillo, Michael',
#  593871: 'Polanco, Jorge',
#  543939: 'Wong, Kolten',
#  425877: 'Molina, Yadier',
#  545350: 'Marisnick, Jake',
#  541645: 'García, Avisaíl',
#  572816: 'Dickerson, Corey',
#  641933: "O'Neill, Tyler",
#  544369: 'Gregorius, Didi',
#  671277: 'García, Luis',
#  518792: 'Heyward, Jason',
#  664774: 'Wade Jr., LaMonte',
#  643565: 'Tauchman, Mike',
#  542364: 'Ortega, Rafael',
#  595943: 'Evans, Phillip',
#  553993: 'Suárez, Eugenio',
#  591720: 'Torreyes, Ronald',
#  606132: 'Tapia, Raimel',
#  502210: 'Reddick, Josh',
#  519058: 'Moustakas, Mike',
#  598265: 'Bradley Jr., Jackie',
#  608369: 'Seager, Corey',
#  527038: 'Flores, Wilmer',
#  456715: 'Cain, Lorenzo',
#  670042: 'Raley, Luke',
#  673357: 'Robert, Luis',
#  641857: 'McMahon, Ryan',
#  661388: 'Contreras, William',
#  656371: 'Díaz, Isan',
#  444489: 'Piña, Manny',
#  592178: 'Bryant, Kris',
#  592826: 'Velasquez, Vince',
#  656413: 'Fairchild, Stuart',
#  605113: 'Ahmed, Nick',
#  669242: 'Edman, Tommy',
#  621035: 'Taylor, Chris',
#  669222: 'Senzel, Nick',
#  676801: 'McCormick, Chas',
#  605200: 'Davies, Zach',
#  621446: 'Brinson, Lewis',
#  673490: 'Kim, Ha-Seong',
#  570481: 'González, Erik',
#  605119: 'Anderson, Brian',
#  645302: 'Robles, Victor',
#  660294: 'Tsutsugo, Yoshi',
#  571970: 'Muncy, Max',
#  448179: 'Hill, Rich',
#  543333: 'Hosmer, Eric',
#  595777: 'Profar, Jurickson',
#  572041: 'Pollock, AJ',
#  665487: 'Tatis Jr., Fernando',
#  624585: 'Soler, Jorge',
#  649966: 'Urías, Luis',
#  643265: 'Cooper, Garrett',
#  543068: 'Cron, C.J.',
#  607345: 'Smith, Kevan',
#  607054: 'Peterson, Jace',
#  663898: 'Rodgers, Brendan',
#  596019: 'Lindor, Francisco',
#  641856: 'McKinney, Billy',
#  609280: 'Andújar, Miguel',
#  650402: 'Torres, Gleyber',
#  663567: 'Lambert, Peter',
#  546318: 'Herrera, Odúbel',
#  624415: 'Biggio, Cavan',
#  605170: 'Caratini, Victor',
#  676391: 'Clement, Ernie',
#  664761: 'Bohm, Alec',
#  663586: 'Riley, Austin',
#  669256: 'Solak, Nick',
#  571976: 'Myers, Wil',
#  664238: 'Moore, Dylan',
#  643396: 'Kiner-Falefa, Isiah',
#  666135: 'Kirilloff, Alex',
#  571448: 'Arenado, Nolan',
#  462101: 'Andrus, Elvis',
#  514888: 'Altuve, Jose',
#  596847: 'Choi, Ji-Man',
#  650391: 'Jiménez, Eloy',
#  476704: 'Lowrie, Jed',
#  571718: 'Goodwin, Brian',
#  602922: 'Rondón, José',
#  657077: 'Verdugo, Alex',
#  605548: 'Zimmer, Bradley',
#  650489: 'Castro, Willi',
#  605412: 'Panik, Joe',
#  650333: 'Arraez, Luis',
#  623205: 'Velazquez, Andrew',
#  621433: 'Phillips, Brett',
#  621563: 'Wendle, Joey',
#  572761: 'Carpenter, Matt',
#  621028: 'Newman, Kevin',
#  663886: 'Stephenson, Tyler',
#  518586: 'Culberson, Charlie',
#  621043: 'Correa, Carlos',
#  455117: 'Maldonado, Martín',
#  500871: 'Escobar, Eduardo',
#  543105: 'Dickerson, Alex',
#  606992: 'Haase, Eric',
#  663538: 'Hoerner, Nico',
#  643217: 'Benintendi, Andrew',
#  670032: 'Lopez, Nicky',
#  516782: 'Marte, Starling',
#  665742: 'Soto, Juan',
#  663647: "Hayes, Ke'Bryan",
#  543877: 'Vázquez, Christian',
#  641487: 'Crawford, J.P.',
#  571466: 'Barnhart, Tucker',
#  458731: 'Gardner, Brett',
#  641470: 'Collins, Zack',
#  668804: 'Reynolds, Bryan',
#  570731: 'Schoop, Jonathan',
#  664023: 'Happ, Ian',
#  553902: 'Astudillo, Willians',
#  593160: 'Merrifield, Whit',
#  663993: 'Lowe, Nathaniel',
#  623993: 'Santander, Anthony',
#  620443: 'Torrens, Luis',
#  519317: 'Stanton, Giancarlo',
#  572233: 'Walker, Christian',
#  669257: 'Smith, Will',
#  664034: 'France, Ty',
#  502110: 'Martinez, J.D.',
#  647351: 'Toro, Abraham',
#  592192: 'Canha, Mark',
#  595956: 'Gallagher, Cam',
#  467092: 'Ramos, Wilson',
#  649557: 'Díaz, Aledmys',
#  572191: 'Taylor, Michael A.',
#  669720: 'Hays, Austin',
#  502054: 'Pham, Tommy',
#  573262: 'Yastrzemski, Mike',
#  642086: 'Smith, Dominic',
#  542303: 'Ozuna, Marcell',
#  543543: 'Miller, Brad',
#  516770: 'Castro, Starlin',
#  453568: 'Blackmon, Charlie',
#  642731: 'Estrada, Thairo',
#  676701: 'Trejo, Alan',
#  624428: 'Frazier, Adam',
#  592866: 'Williams, Trevor',
#  446334: 'Longoria, Evan',
#  642423: 'Sierra, Magneuris',
#  592518: 'Machado, Manny',
#  456781: 'Solano, Donovan',
#  607043: 'Nimmo, Brandon',
#  594807: 'Duvall, Adam',
#  592273: 'Drury, Brandon',
#  642715: 'Adames, Willy',
#  543592: 'Nola, Austin',
#  656305: 'Chapman, Matt',
#  542340: 'Villar, Jonathan',
#  621020: 'Swanson, Dansby',
#  596115: 'Story, Trevor',
#  660271: 'Ohtani, Shohei',
#  656541: 'Hilliard, Sam',
#  518692: 'Freeman, Freddie',
#  575929: 'Contreras, Willson',
#  592206: 'Castellanos, Nick',
#  608348: 'Kelly, Carson',
#  571740: 'Hamilton, Billy',
#  600303: 'La Stella, Tommy',
#  624414: 'Arroyo, Christian',
#  657656: 'Laureano, Ramón',
#  640461: 'Pinder, Chad',
#  641829: 'Martin, Jason',
#  664058: 'Fletcher, David',
#  621566: 'Olson, Matt',
#  543305: 'Hicks, Aaron',
#  608324: 'Bregman, Alex',
#  592669: 'Renfroe, Hunter',
#  543807: 'Springer, George',
#  663611: 'Madrigal, Nick',
#  660162: 'Moncada, Yoán',
#  665489: 'Guerrero Jr., Vladimir',
#  606213: 'Mercedes, Yermín',
#  545358: 'Stassi, Max',
#  665120: 'Walsh, Jared',
#  624512: 'McGuire, Reese',
#  592450: 'Judge, Aaron',
#  593643: 'Alberto, Hanser',
#  641505: 'Davis, Jonathan',
#  521692: 'Perez, Salvador',
#  543228: 'Gomes, Yan',
#  646240: 'Devers, Rafael',
#  503556: 'Gonzalez, Marwin',
#  608686: 'Mayfield, Jack',
#  664728: 'Isbel, Kyle',
#  457759: 'Turner, Justin',
#  623520: 'Bote, David',
#  621512: 'Nido, Tomás',
#  595981: 'Heineman, Scott',
#  474832: 'Belt, Brandon',
#  606466: 'Marte, Ketel',
#  593934: 'Sanó, Miguel',
#  666158: 'Lux, Gavin',
#  595879: 'Báez, Javier',
#  452678: 'Cabrera, Asdrúbal',
#  547989: 'Abreu, José',
#  571771: 'Hernández, Enrique',
#  677551: 'Franco, Wander',
#  647304: 'Naylor, Josh',
#  453943: 'Frazier, Todd',
#  570482: 'Urshela, Gio',
#  642082: 'Sisco, Chance',
#  623912: 'Ramirez, Harold',
#  608331: 'Fried, Max',
#  621466: 'Stewart, DJ',
#  544725: 'García, Leury',
#  641820: 'Mancini, Trey',
#  593428: 'Bogaerts, Xander',
#  642180: 'Wade, Tyler',
#  642708: 'Rosario, Amed',
#  680911: 'Miller, Owen',
#  642162: 'Valaika, Pat',
#  518626: 'Donaldson, Josh',
#  663662: 'Cameron, Daz',
#  514917: 'Hernández, César',
#  656252: 'Bradley, Bobby',
#  656941: 'Schwarber, Kyle',
#  578428: 'Iglesias, José',
#  628451: 'Ibáñez, Andy',
#  666182: 'Bichette, Bo',
#  663616: 'Larnach, Trevor',
#  641531: 'Dozier, Hunter',
#  594694: 'Difo, Wilmer',
#  669203: 'Burnes, Corbin',
#  650559: 'De La Cruz, Bryan',
#  622534: 'Margot, Manuel',
#  453286: 'Scherzer, Max',
#  596056: 'Nogowski, John',
#  657557: 'DeJong, Paul',
#  664040: 'Lowe, Brandon',
#  592200: 'Casali, Curt',
#  444876: 'Escobar, Alcides',
#  408234: 'Cabrera, Miguel',
#  660821: 'Sánchez, Jesús',
#  595751: 'Alfaro, Jorge',
#  656976: 'Smith, Pavin',
#  642133: 'Tellez, Rowdy',
#  642336: 'Mejía, Francisco',
#  656577: 'Jackson, Alex',
#  672284: 'Kelenic, Jarred',
#  592885: 'Yelich, Christian',
#  608385: 'Winker, Jesse',
#  628450: 'Hernandez, Yadiel',
#  664913: 'Brown, Seth',
#  660670: 'Acuña Jr., Ronald',
#  596103: 'Slater, Austin',
#  605137: 'Bell, Josh',
#  656555: 'Hoskins, Rhys',
#  547180: 'Harper, Bryce',
#  623167: 'Flexen, Chris',
#  542583: 'Aguilar, Jesús',
#  573131: 'Ruf, Darin',
#  595281: 'Kiermaier, Kevin',
#  656514: 'Haseley, Adam',
#  595453: 'Wallach, Chad',
#  656716: 'McKinstry, Zach',
#  670541: 'Alvarez, Yordan',
#  543760: 'Semien, Marcus',
#  666915: 'Dalbec, Bobby',
#  545341: 'Grichuk, Randal',
#  542932: 'Berti, Jon',
#  663757: 'Grisham, Trent',
#  572122: 'Seager, Kyle',
#  605141: 'Betts, Mookie',
#  624413: 'Alonso, Pete',
#  516416: 'Segura, Jean',
#  641355: 'Bellinger, Cody',
#  457705: 'McCutchen, Andrew',
#  657061: 'Tucker, Cole',
#  666971: 'Gurriel Jr., Lourdes',
#  621107: 'Eflin, Zach',
#  592325: 'Gamel, Ben',
#  506703: 'Sanchez, Adrián',
#  664983: 'McCarthy, Jake',
#  519390: 'Vogt, Stephen',
#  425784: 'Rivera, René',
#  624641: 'Sosa, Edmundo',
#  663457: 'Nootbaar, Lars',
#  467793: 'Santana, Carlos',
#  571657: 'Farmer, Kyle',
#  594777: 'Calhoun, Kole',
#  664056: 'Bader, Harrison',
#  624513: 'Nuñez, Dom',
#  489119: 'Miley, Wade',
#  596146: 'Kepler, Max',
#  500743: 'Rojas, Miguel',
#  666185: 'Carlson, Dylan',
#  641553: 'Engel, Adam',
#  519048: 'Moreland, Mitch',
#  593590: 'Rivas, Webster',
#  444482: 'Peralta, David',
#  595978: 'Hedges, Austin',
#  641786: 'Lewis, Kyle',
#  665926: 'Giménez, Andrés',
#  571745: 'Haniger, Mitch',
#  608336: 'Gallo, Joey',
#  656537: 'Hill, Derek',
#  656811: "O'Hearn, Ryan",
#  488726: 'Brantley, Michael',
#  642721: 'Gutierrez, Kelvin',
#  666969: 'García, Adolis',
#  656847: 'Peters, DJ',
#  493329: 'Gurriel, Yuli',
#  663624: 'Mountcastle, Ryan',
#  676694: 'Meyers, Jake',
#  602074: 'Daza, Yonathan',
#  643446: 'McNeil, Jeff',
#  650490: 'Díaz, Yandy',
#  608070: 'Ramírez, José',
#  622110: 'Duffy, Matt',
#  592567: 'Moran, Colin',
#  643289: 'Dubón, Mauricio',
#  641313: 'Anderson, Tim',
#  570256: 'Polanco, Gregory',
#  543063: 'Crawford, Brandon',
#  666176: 'Adell, Jo',
#  621550: 'Wisdom, Patrick',
#  600869: 'Candelario, Jeimer',
#  643376: 'Jansen, Danny',
#  668227: 'Arozarena, Randy',
#  518735: 'Grandal, Yasmani',
#  606192: 'Hernández, Teoscar',
#  474568: 'Mercer, Jordy',
#  640457: 'Meadows, Austin',
#  596825: 'García, Robel',
#  405395: 'Pujols, Albert',
#  669221: 'Murphy, Sean',
#  607208: 'Turner, Trea',
#  664702: 'Straw, Myles',
#  592743: 'Simmons, Andrelton',
#  641432: 'Calhoun, Willie',
#  571980: 'Naquin, Tyler',
#  683734: 'Vaughn, Andrew',
#  641598: 'Garver, Mitch',
#  670351: 'Rojas, Jose',
#  435559: 'Suzuki, Kurt',
#  572228: 'Voit, Luke',
#  592348: 'Goodrum, Niko',
#  607732: 'Stallings, Jacob',
#  592626: 'Pederson, Joc',
#  663656: 'Tucker, Kyle',
#  670764: 'Walls, Taylor',
#  656775: 'Mullins, Cedric',
#  650859: 'Rengifo, Luis',
#  543510: 'McCann, James',
#  650968: 'Pozo, Yohel',
#  458015: 'Votto, Joey',
#  622491: 'Castillo, Luis',
#  657041: 'Thomas, Lane',
#  621002: 'Robertson, Daniel',
#  543432: 'Lavarnway, Ryan',
#  641658: 'Hampson, Garrett',
#  608577: 'Mazara, Nomar',
#  502671: 'Goldschmidt, Paul',
#  542992: 'Burns, Andy',
#  624424: 'Conforto, Michael',
#  596295: 'Gomber, Austin',
#  666198: 'Kieboom, Carter',
#  518934: 'LeMahieu, DJ',
#  605612: 'Castro, Harold',
#  459964: 'Joyce, Matt',
#  596142: 'Sánchez, Gary',
#  607680: 'Pillar, Kevin',
#  572287: 'Zunino, Mike',
#  669016: 'Marsh, Brandon',
#  594809: 'Eaton, Adam',
#  621311: 'Dahl, David',
#  602104: 'Urías, Ramón',
#  641584: 'Fraley, Jake',
#  664901: 'Mendick, Danny',
#  614177: 'Reyes, Franmil',
#  641680: 'Heim, Jonah',
#  657108: 'White, Evan',
#  663697: 'India, Jonathan',
#  621458: 'Ríos, Edwin',
#  518595: "d'Arnaud, Travis",
#  642165: 'VanMeter, Josh',
#  660688: 'Ruiz, Keibert',
#  621438: 'Taylor, Tyrone',
#  641796: 'Locastro, Tim',
#  680777: 'Jeffers, Ryan',
#  641645: 'Guillorme, Luis',
#  501303: 'Adrianza, Ehire',
#  547379: 'Pérez, Roberto',
#  553869: 'Díaz, Elias',
#  607455: 'Banda, Anthony',
#  596059: 'Odor, Rougned',
#  670712: 'Brosseau, Mike',
#  543685: 'Rendon, Anthony',
#  664059: 'Haggerty, Sam',
#  606988: 'Greiner, Grayson',
#  669289: 'Espinal, Santiago',
#  663728: 'Raleigh, Cal',
#  668942: 'Rojas, Josh',
#  608384: 'Williams, Nick',
#  667670: 'Rooker, Brent',
#  660620: 'Araúz, Jonathan',
#  665862: 'Chisholm Jr., Jazz',
#  643524: 'Schwindel, Frank',
#  592656: 'Ramos, Henry',
#  622569: 'Reyes, Pablo',
#  621111: 'Buehler, Walker',
#  443558: 'Cruz, Nelson',
#  668800: 'Knizner, Andrew',
#  543294: 'Hendricks, Kyle',
#  663837: 'Vierling, Matt',
#  596117: 'Stubbs, Garrett',
#  606299: 'Peraza, José',
#  656403: 'Ellis, Drew',
#  605361: 'Martini, Nick',
#  624431: 'Trevino, Jose',
#  542255: 'Inciarte, Ender',
#  658069: 'Fuentes, Joshua',
#  456034: 'Price, David',
#  519299: 'Sogard, Eric',
#  642851: 'Wynns, Austin',
#  607536: 'Freeland, Kyle',
#  641154: 'López, Pablo',
#  642201: 'White, Eli',
#  608700: 'Plawecki, Kevin',
#  594798: 'deGrom, Jacob',
#  608596: 'Murphy, Tom',
#  572039: 'Piscotty, Stephen',
#  630105: 'Cronenworth, Jake',
#  543257: 'Grossman, Robbie',
#  663330: 'Jones, Jahmai',
#  605400: 'Nola, Aaron',
#  665155: 'Maton, Nick',
#  641943: 'Palacios, Josh',
#  542454: 'Santana, Danny',
#  621006: 'Martin, Richie',
#  643393: 'Kemp, Tony',
#  664057: 'Stevenson, Andrew',
#  642211: 'Williams, Justin',
#  445055: 'Jay, Jon',
#  572008: 'Owings, Chris',
#  519203: 'Rizzo, Anthony',
#  501981: 'Davis, Khris',
#  642092: 'Smith, Riley',
#  595909: 'Cave, Jake',
#  621439: 'Buxton, Byron',
#  605288: 'Houser, Adrian',
#  665561: 'Marchan, Rafael',
#  666801: 'Castro, Rodolfo',
#  606157: 'Aquino, Aristides',
#  543309: 'Higashioka, Kyle',
#  666211: 'Trammell, Taylor',
#  628338: 'Heredia, Guillermo',
#  657757: 'Sheets, Gavin',
#  668731: 'Baddoo, Akil',
#  664850: 'Mazeika, Patrick',
#  501571: 'Lagares, Juan',
#  656509: 'Harrison, Monte',
#  605204: 'Davis, J.D.',
#  592696: 'Rosario, Eddie',
#  506702: 'León, Sandy',
#  650331: 'Díaz, Lewin',
#  592663: 'Realmuto, J.T.',
#  502481: 'Dyson, Jarrod',
#  608701: 'Refsnyder, Rob',
#  553882: 'Narváez, Omar',
#  622666: 'Camargo, Johan',
#  592332: 'Gausman, Kevin',
#  660829: 'Park, Hoy',
#  665759: 'Rosso, Ramón',
#  546990: 'Alford, Anthony',
#  456501: 'Cueto, Johnny',
#  605421: 'Perez, Michael',
#  641343: 'Bauers, Jake',
#  670084: 'Heath, Nick',
#  596748: 'Franco, Maikel',
#  640458: 'Mercado, Oscar',
#  594838: 'Gosselin, Phil',
#  664314: 'Florial, Estevan',
#  645801: 'Ford, Mike',
#  643418: 'Long Jr., Shed',
#  591971: 'Valera, Breyvic',
#  663845: 'Rivas, Alfonso',
#  571788: 'Holt, Brock',
#  670097: 'Short, Zack',
#  572204: 'Thompson, Trayce',
#  543281: 'Harrison, Josh',
#  656427: 'Flaherty, Jack',
#  642727: 'Alcántara, Sergio',
#  672701: 'Devers, José',
#  645261: 'Alcantara, Sandy',
#  607468: 'Blandino, Alex',
#  669060: 'Wilson, Bryse',
#  643436: 'McBroom, Ryan',
#  501659: 'Almonte, Abraham',
#  614173: 'Cordero, Franchy',
#  642736: 'Leyba, Domingo',
#  502273: 'Freeman, Mike',
#  641778: 'Lauer, Eric',
#  600474: 'Severino, Pedro',
#  658668: 'Olivares, Edward',
#  425794: 'Wainwright, Adam',
#  621493: 'Ward, Taylor',
#  662139: 'Varsho, Daulton',
#  670370: 'Young, Andrew',
#  475582: 'Zimmerman, Ryan',
#  663897: 'Williams, Luke',
#  592530: 'Marmolejos, José',
#  520471: 'Galvis, Freddy',
#  656180: 'Adams, Riley',
#  571431: 'Adams, Matt',
#  656582: 'Joe, Connor',
#  457708: 'Upton, Justin',
#  622100: 'Jones, Taylor',
#  543308: 'Hicks, John',
#  608671: 'Jankowski, Travis',
#  519222: 'Romine, Austin',
#  592254: 'De León, José',
#  467827: 'Parra, Gerardo',
#  669288: 'Johnson, Daniel',
#  571875: 'Lamb, Jake',
#  663743: 'Fortes, Nick',
#  502624: 'Anderson, Chase',
#  670770: 'Friedl, TJ',
#  665750: 'Taveras, Leody',
#  657434: "O'Grady, Brian",
#  543768: 'Shaw, Travis',
#  488771: 'Castro, Jason',
#  664141: 'Brubaker, JT',
#  605131: 'Barnes, Austin',
#  668663: 'Barrera, Tres',
#  596129: 'Vogelbach, Daniel',
#  669374: 'Hiura, Keston',
#  672386: 'Kirk, Alejandro',
#  656669: 'Luplow, Jordan',
#  621453: 'Duggar, Steven',
#  607461: 'Beaty, Matt',
#  669456: 'Bieber, Shane',
#  446653: 'Lobaton, Jose',
#  547172: 'Wolters, Tony',
#  613564: 'Vosler, Jason',
#  594988: 'Schebler, Scott',
#  663630: 'McKenna, Ryan',
#  622682: 'Reyes, Victor',
#  664247: 'Garlick, Kyle',
#  666163: 'Rortvedt, Ben',
#  547004: 'Ruiz, Rio',
#  543594: 'Nolin, Sean',
#  656896: 'Rivera, Emmanuel',
#  592444: 'Jones, JaCoby',
#  594986: 'Ryan, Kyle',
#  657011: 'Stokes Jr., Troy',
#  666120: 'Anderson, Ian',
#  595284: 'Knapp, Andrew',
#  641561: 'Fargas, Johneshwy',
#  664874: 'Zavala, Seby',
#  660623: 'Ynoa, Huascar',
#  477132: 'Kershaw, Clayton',
#  656185: 'Allen, Greg',
#  571578: 'Corbin, Patrick',
#  624503: 'Gordon, Nick',
#  660644: 'Bruján, Vidal',
#  665482: 'Celestino, Gilberto',
#  621450: 'Bolt, Skye',
#  642547: 'Peralta, Freddy',
#  656546: 'Hoffman, Jeff',
#  542963: 'Brantly, Rob',
#  602080: 'Castillo, Erick',
#  592716: 'Sampson, Adrian',
#  642456: 'Barrera, Luis',
#  622761: 'Mateo, Jorge',
#  457803: 'Bruce, Jay',
#  600524: 'Núñez, Renato',
#  621011: 'Schrock, Max',
#  545121: 'Vargas, Ildemaro',
#  664789: "Tom, Ka'ai",
#  605353: 'Machín, Vimael',
#  657193: 'Alvarez, Eddy',
#  605397: 'Musgrove, Joe',
#  545333: 'Bauer, Trevor',
#  461865: 'Romine, Andrew',
#  502179: 'Espino, Paolo',
#  628711: 'Urías, Julio',
#  547001: 'Poteet, Cody',
#  656605: 'Keller, Mitch',
#  605507: 'Thompson, Zach',
#  656308: 'Chavis, Michael',
#  546991: 'Almora Jr., Albert',
#  656364: 'Deichmann, Greg',
#  609275: 'Mondesi, Adalberto',
#  644374: 'Chang, Yu',
#  605452: 'Ross, Joe',
#  666213: 'Welker, Colton',
#  642221: 'Wong, Kean',
#  455139: 'Chirinos, Robinson',
#  621348: 'Clay, Sam',
#  545361: 'Trout, Mike',
#  605244: 'Garcia, Aramis',
#  621532: 'Bemboom, Anthony',
#  640449: 'Frazier, Clint',
#  608422: 'Godoy, José',
#  600858: 'Arteaga, Humberto',
#  506433: 'Darvish, Yu',
#  676840: 'Peacock, Matt',
#  607111: 'Wilson, Jacob',
#  571912: 'Maile, Luke',
#  518774: 'Harvey, Matt',
#  641914: 'Neuse, Sheldon',
#  669134: 'Campusano, Luis',
#  592261: 'DeShields, Delino',
#  666160: 'Moniak, Mickey',
#  452657: 'Lester, Jon',
#  622608: 'Senzatela, Antonio',
#  665833: 'Cruz, Oneil',
#  621005: 'Lopes, Tim',
#  666205: 'Muller, Kyle',
#  457727: 'Maybin, Cameron',
#  669432: 'Rogers, Trevor',
#  543101: 'DeSclafani, Anthony',
#  592767: 'Smyly, Drew',
#  665506: 'Pache, Cristian',
#  572863: 'Garneau, Dustin',
#  571918: 'Marrero, Deven',
#  664731: 'Higgins, P.J.',
#  665861: 'Rivero, Sebastian',
#  622168: 'Muñoz, Yairo',
#  657140: 'Wright, Kyle',
#  596451: 'Quinn, Roman',
#  664062: 'Gonsolin, Tony',
#  519306: 'Souza Jr., Steven',
#  677960: 'Weathers, Ryan',
#  641924: 'Nottingham, Jacob',
#  676480: 'Barrero, Jose',
#  468504: 'Chacín, Jhoulys',
#  547942: 'Kim, Kwang Hyun',
#  642350: 'Siri, Jose',
#  643377: 'Jax, Griffin',
#  621500: 'Mathisen, Wyatt',
#  668670: 'Rogers, Jake',
#  669394: 'Burger, Jake',
#  518516: 'Bumgarner, Madison',
#  518960: 'Lucroy, Jonathan',
#  458708: 'Tomlin, Josh',
#  608344: 'Irvin, Cole',
#  606993: 'Hager, Jake',
#  606115: 'Arcia, Orlando',
#  592346: 'González, Chi Chi',
#  641583: 'Fowler, Dustin',
#  641771: 'Kuhl, Chad',
#  608566: 'Márquez, Germán',
#  664670: 'Lopez, Alejo',
#  493472: 'Campbell, Eric',
#  656467: 'Gittens, Chris',
#  488671: 'Avila, Alex',
#  605504: 'Thomas, Dillon',
#  675656: 'Smith, Kevin',
#  592863: 'Williams, Mason',
#  675649: 'Miller, Brian',
#  680776: 'Duran, Jarren',
#  663853: 'Gonzalez, Romy',
#  663527: 'Nevin, Tyler',
#  641816: 'Mahle, Tyler',
#  666129: 'Garrett, Braxton',
#  657141: 'Yamamoto, Jordan',
#  660634: 'Hernandez, Yonny',
#  642203: 'Widener, Taylor',
#  624133: 'Suárez, Ranger',
#  554430: 'Wheeler, Zack',
#  622268: 'Walton, Donovan',
#  672779: 'Marcano, Tucupita',
#  664068: 'Kingery, Scott',
#  615699: 'Robson, Jacob',
#  534606: 'LaMarre, Ryan',
#  640470: 'Alzolay, Adbert',
#  663799: 'Terry, Curtis',
#  670462: 'Owen, Hunter',
#  502239: 'Cahill, Trevor',
#  621573: 'Dean, Austin',
#  643269: 'Craig, Will',
#  666931: 'Oliva, Jared',
#  608597: 'Guzmán, Ronald',
#  623508: 'Giambrone, Trent',
#  670623: 'Paredes, Isaac',
#  592351: 'Gray, Jon',
#  607231: 'Gant, John',
#  628317: 'Maeda, Kenta',
#  657136: 'Wong, Connor',
#  670768: 'González, Luis',
#  657053: 'Toussaint, Touki',
#  670912: 'Oviedo, Johan',
#  645305: 'Sánchez, Ali',
#  608328: 'De Jong, Chase',
#  592407: 'Holaday, Bryan',
#  641745: 'Keller, Brad',
#  664011: 'Amburgey, Trey',
#  600301: 'Motter, Taylor',
#  663978: 'Paddack, Chris',
#  663905: 'Blankenhorn, Travis',
#  457918: 'Happ, J.A.',
#  541650: 'Pérez, Hernán',
#  592622: 'Payton, Mark',
#  605540: 'Woodruff, Brandon',
#  642028: 'Rogers, Josh',
#  541600: 'Tovar, Wilfredo',
#  664041: 'Davis, Jaylin',
#  518876: 'Kelly, Merrill',
#  656568: 'Hurst, Scott',
#  592836: 'Walker, Taijuan',
#  467055: 'Sandoval, Pablo',
#  668721: 'Henry, Payton',
#  670955: 'Uceta, Edwin',
#  460077: 'Butera, Drew',
#  605483: 'Snell, Blake',
#  622694: 'Hernandez, Elieser',
#  453562: 'Arrieta, Jake',
#  502043: 'Gibson, Kyle',
#  571927: 'Matz, Steven',
#  660731: 'Tejeda, Anderson',
#  607200: 'Fedde, Erick',
#  640444: 'Crowe, Wil',
#  661269: 'Gutierrez, Vladimir',
#  643290: 'Dunn, Justin',
#  656457: 'Gilbert, Tyler',
#  543243: 'Gray, Sonny',
#  596071: 'Peters, Dillon',
#  680963: 'Wilson, Cody',
#  672695: 'Perdomo, Geraldo',
#  663460: 'Bubic, Kris',
#  605346: 'López, Jack',
#  669294: 'Campbell, Paul',
#  656731: 'Megill, Tylor',
#  451594: 'Fowler, Dexter',
#  668820: 'Kranick, Max',
#  450203: 'Morton, Charlie',
#  657277: 'Webb, Logan',
#  663574: 'Santillan, Tony',
#  471911: 'Carrasco, Carlos',
#  592859: 'Wilkerson, Stevie',
#  606336: 'Marté, Luis',
#  621559: 'Moroff, Max',
#  650668: 'Mejía, Humberto',
#  596082: 'Reed, Jake',
#  607430: 'Andreoli, John',
#  656876: 'Rasmussen, Drew',
#  664285: 'Valdez, Framber',
#  501985: 'Minor, Mike',
#  543135: 'Eovaldi, Nathan',
#  607188: 'Faria, Jake',
#  624418: 'Castellani, Ryan',
#  448855: 'Guerra, Junior',
#  523260: 'Kelly, Joe',
#  528748: 'Castellanos, Humberto',
#  573186: 'Stroman, Marcus',
#  596133: 'Weaver, Luke',
#  641682: 'Hendrix, Ryan',
#  666179: 'Beer, Seth',
#  642136: 'Thaiss, Matt',
#  593528: 'Bonifacio, Jorge',
#  669674: 'Long, Sammy',
#  623323: 'Bishop, Braden',
#  644433: 'Tromp, Chadwick',
#  676646: 'Reks, Zach',
#  571945: 'Mikolas, Miles',
#  656821: 'Padlo, Kevin',
#  543089: 'Davis, Taylor',
#  624419: 'Ciuffo, Nick',
#  621008: 'De Goti, Alex',
#  474463: 'Anderson, Brett',
#  542881: 'Anderson, Tyler',
#  656849: 'Peterson, David',
#  592662: 'Ray, Robbie',
#  663698: 'Bart, Joey',
#  592761: 'Smith, Caleb',
#  624522: 'Thompson, Keegan',
#  425772: 'Mathis, Jeff',
#  605233: 'Fisher, Derek',
#  453527: 'Kazmar Jr., Sean',
#  656494: 'Gushue, Taylor',
#  592717: 'Sanchez, Aaron',
#  656883: 'Reetz, Jakson',
#  595375: 'Riddle, JT',
#  663734: 'Neidert, Nick',
#  489334: 'Stammen, Craig',
#  622668: 'Castillo, Ivan',
#  666139: 'Lowe, Josh',
#  453281: 'LeBlanc, Wade',
#  642232: 'Yarbrough, Ryan',
#  548389: 'Stripling, Ross',
#  669008: 'Dawson, Ronnie',
#  607219: 'Romano, Sal',
#  519043: 'Moore, Matt',
#  641999: 'Ray, Corey',
#  640455: 'Manaea, Sean',
#  666137: 'Lee, Khalil',
#  518902: 'Kozma, Pete',
#  672335: 'Pérez, Cionel',
#  621261: 'Oswalt, Corey',
#  667297: 'Nance, Tommy',
#  643327: 'Godley, Zack',
#  622072: 'Wood, Alex',
#  667463: 'King, John',
#  641540: 'Dunning, Dane',
#  676220: 'Elledge, Seth',
#  547176: 'Camarena, Daniel',
#  664119: 'Allen, Austin',
#  675921: 'Howard, Spencer',
#  431148: 'Kazmir, Scott',
#  621052: 'Reyes, Alex',
#  656548: 'Holloway, Jordan',
#  670970: 'Morejon, Adrian',
#  643256: 'Cimber, Adam',
#  621219: 'Mills, Alec',
#  664192: 'Lucchesi, Joey',
#  593372: 'Martínez, Carlos',
#  615698: 'Quantrill, Cal',
#  596049: 'Morimando, Shawn',
#  593423: 'Montas, Frankie',
#  664199: 'Clarke, Taylor',
#  543475: 'Lyles, Jordan',
#  656954: 'Sheffield, Justus',
#  544931: 'Strasburg, Stephen',
#  608371: 'Sims, Lucas',
#  622503: 'Crismatt, Nabil',
#  595191: 'Eickhoff, Jerad',
#  666200: 'Luzardo, Jesús',
#  676477: 'Whitlock, Garrett',
#  668678: 'Gallen, Zac',
#  571676: 'Frankoff, Seth',
#  656288: 'Canning, Griffin',
#  640464: 'Stewart, Kohl',
#  656686: 'Martin, Corbin',
#  641482: 'Cortes, Nestor',
#  677651: 'Garcia, Luis',
#  571510: 'Boyd, Matthew',
#  621076: 'Kaprielian, James',
#  663465: 'Allard, Kolby',
#  663765: 'Woodford, Jake',
#  476594: 'Stock, Robert',
#  572070: 'Richards, Garrett',
#  501381: 'Pineda, Michael',
#  641447: 'Castano, Daniel',
#  598286: 'Ramirez, Nick',
#  572971: 'Keuchel, Dallas',
#  595465: 'Winkler, Dan',
#  608718: 'Suter, Brent',
#  663474: 'McKenzie, Triston',
#  607229: 'Gsellman, Robert',
#  656302: 'Cease, Dylan',
#  592419: 'Hoying, Jared',
#  607560: 'Harper, Ryne',
#  622766: 'Diaz, Miguel',
#  605347: 'López, Jorge',
#  664076: 'Cleavinger, Garrett',
#  641929: 'Odom, Joseph',
#  663776: 'Sandoval, Patrick',
#  488984: 'Hunter, Tommy',
#  657006: 'Steele, Justin',
#  518858: 'Jones, Nate',
#  595928: 'Curtiss, John',
#  669622: 'Bender, Anthony',
#  519326: 'Strickland, Hunter',
#  608723: 'Voth, Austin',
#  656794: 'Newcomb, Sean',
#  608337: 'Giolito, Lucas',
#  593958: 'Rodriguez, Eduardo',
#  446321: 'Detwiler, Ross',
#  607625: 'Lugo, Seth',
#  664074: 'Ponce, Cody',
#  669160: 'May, Dustin',
#  571760: 'Heaney, Andrew',
#  605164: 'Bundy, Dylan',
#  608334: 'Fulmer, Carson',
#  542947: 'Bleier, Richard',
#  664208: 'Maton, Phil',
#  622446: 'Rodriguez, Jefry',
#  623182: 'Kivlehan, Patrick',
#  647315: 'Pop, Zach',
#  667376: 'Sánchez, Miguel',
#  669145: 'Zimmermann, Bruce',
#  502171: 'Cobb, Alex',
#  622088: 'Antone, Tejay',
#  607644: 'Means, John',
#  669952: 'White, Mitch',
#  596001: 'Junis, Jakob',
#  676900: 'Dorow, Ryan',
#  621121: 'McCullers Jr., Lance',
#  663753: 'Knehr, Reiss',
#  543351: 'Jackson, Jay',
#  547179: 'Lorenzen, Michael',
#  656756: 'Montgomery, Jordan',
#  571946: 'Miller, Shelby',
#  672851: 'Adon, Joan',
#  680686: 'Gray, Josiah',
#  458681: 'Lynn, Lance',
#  596057: 'Norris, Daniel',
#  656212: 'Barnes, Charlie',
#  657097: 'Webb, Jacob',
#  500779: 'Quintana, José',
#  672282: 'Detmers, Reid',
#  669211: 'Akin, Keegan',
#  663554: 'Mize, Casey',
#  641360: 'Bickford, Phil',
#  656629: 'Kopech, Michael',
#  607074: 'Rodón, Carlos',
#  607067: 'Rea, Colin',
#  606424: 'García, Jarlín',
#  623437: 'Topa, Justin',
#  666201: 'Manoah, Alek',
#  655889: 'Rodríguez, Manuel',
#  608349: 'Knebel, Corey',
#  668723: 'Vilade, Ryan',
#  676050: 'Naughton, Packy',
#  656354: 'Davis, Austin',
#  621074: 'Rucker, Michael',
#  623485: 'Goudeau, Ashton',
#  453343: 'Melancon, Mark',
#  595798: 'Alaniz, R.J.',
#  665665: 'Sanmartin, Reiver',
#  501625: 'Álvarez, José',
#  570632: 'Ureña, José',
#  543056: 'Coulombe, Danny',
#  547943: 'Ryu, Hyun Jin'}

# %%
event_df = pd.read_csv('MAIN.csv')
event_df=event_df[['batter', 'player_name']]
event_df = event_df.drop_duplicates()
event_dict = {}

# %%
import pandasql

# %%
player_df = pd.read_csv('MAIN.csv')

# %%
from pandasql import sqldf

# %%
mysql = lambda q: player_df(q, globals())

# %%
mysql("SELECT * FROM player_df LIMIT 5;")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f330a0c5f0b1> in <module>
# ----> 1 mysql("SELECT * FROM player_df LIMIT 5;")
#
# <ipython-input-19-81a719e6ef43> in <lambda>(q)
# ----> 1 mysql = lambda q: player_df(q, globals())
#
# TypeError: 'DataFrame' object is not callable
